# %% [markdown]
# # Pintar de blanco cuadriculas
#
#
# ## Figura 1 (primera solución)
#
# 1. Move one square right
#
# 2. Fill-in square with color white
#
# 3. Move one square right
#
# 4. Fill-in square with color white
#
# 5. Move one square right
#
# 6. Move one square down
#
# 7. Fill-in square with color white
#
# 8. Move one square left
#
# 9. Move one square left
#
# 10. Move one square left
#
# 11. Fill-in square with color white
#
#
#
# ## Figura 1 (segunda solución)
#
# 1. Move one square down
#
# 2. Fill-in square with color white
#
# 3. Move one square right
#
# 4. Move one square up
#
# 5. Fill-in square with color white
#
# 6. Move one square right
#
# 7. Fill-in square with color white
#
# 8. Move one square down
#
# 9. Move one square left
#
# 10. Fill-in square with color white
#
#
#
# ## Figura 6
#
# 1. Move one square right
#
# 2. Fill-in square with color white
#
# 3. Move one square down
#
# 4. Fill-in square with color white
#
# 5. Move one square down
#
# 6. Fill-in square with color white
#
# 7. Move one square down
#
# 8. Fill-in square with color white
#
# 9. Move one square left
#
# 10. Fill-in square with color white
#
# 11. Move one square up
#
# 12. Fill-in square with color white
#
# 13. Move one square up
#
# 14. Fill-in square with color white
#
# 15. Move one square up
#
# 16. Fill-in square with color white
#
# 17. Move one square up
